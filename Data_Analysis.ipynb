# %% [markdown]
# <center>
# <span style="line-height:32px;display:block;font-size:32px;font-weight:bolder;">Cardiovascular Study Dataset</span>
# <span style="line-height:32px;display:block;font-size:14px;font-weight:bold;color:gray;">Predicting Heart Disease of Patients</span>
# <br>
# <br>
# <img src="./images/image-01.jpg?1" />
# <br>
# <br>
# <span style="line-height:32px;display:block;font-size:16px;font-weight:bold;">University of Catania - Master Degree in Data Science</span>
# <span style="line-height:32px;display:block;font-size:16px;font-weight:bold;">Academic year 2022/2023</h3>
# <span style="line-height:32px;display:block;font-size:16px;font-weight:bold;">Project notebook or Fondamenti di Analisi Data</span>
# <br>
# <br>
# <br>
# <span style="line-height:32px;display:block;font-size:16px;font-weight:bold;">Francesco Grasso - 1000029392</span>
# <span style="line-height:32px;display:block;font-size:16px;font-weight:bold;">Teachers: Giovanni Gallo - Paolo Marco Riela</span>
# </center>

# %%
# %%javascript
# $.getScript('scripts/table_of_contents.js')
# //This cell is needed only to creat§ the table of contents

# %% [markdown]
# <p style="line-height:32px;display:block;font-size:32px;font-weight:bolder;" id="toctitle">Table of Contents</p>
# <div id="toc"></div>

# %% [markdown]
# <h1>1 Introduction</h1>

# %% [markdown]
# <h2>1.1 Purposes</h2>
#
# <p>World Health Organization has estimated 12 million deaths occur worldwide, every year due to Heart diseases. Half the deaths in the United States and other developed countries are due to cardio vascular diseases. The early prognosis of cardiovascular diseases can aid in making decisions on lifestyle changes in high risk patients and in turn reduce the complications.</p>
#
# <p>This notebook main purpose was to study one of the many Framingham Heart Diseases datasets. The research on this dataset was organized in these three main sections:</p>
#
# <ol>
#     <li>Section one: Data Analysis and Data Refactor (Chapter 3)</li>
#     <li>Section two: Descriptive statistics on the data (Chapter 4)</li>
#     <li>Section three: Classification (Chapter 5)</li>
# </ol>

# %% [markdown]
# <h2>1.2 About the dataset</h2>
#
# <p>The dataset is publically available on the Kaggle <a href="https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset">website</a>. It contains the data of over 4000 residents of the town of Framingham, Massachusetts. The meaning of this dataset is to determine if the patients will suffer at least a CHD (coronary heart disease) or not in ten years.</p>
#
# <p>To be able to reach this goal, for each person there are fifteen attributes divided in three groups: demographic, medical history of the patient and his or her current medical status (such as BMI, heart rate etc). Each attribute is a potential risk factor to determine if the patient will suffer a CHD in ten years.</p>
#
# <p>Here the list of the attributes:</p>
#
# <ol>
#     <li>Demographic
#         <ul>
#             <li>sex: male (value 1) or female (value 0)</li>
#             <li>age: Number of years as an integer number</li>
#             <li>education: Some High School (value 1); High School Degree or GED (value 2); Some College or Vocational School (value 3); College Degree or Vocational School Degree (value4)</li>
#             <li>currentSmoker: Smoker (1) or Nonsmoker (0)</li>
#             <li>cigsPerDay: Average number of cigarettes smoked per day as an integer (0 for nonsmokers)</li>
#         </ul>
#     </li>
#     <li>Medical History of the patient
#         <ul>
#             <li>BPMeds: Whether the patient is on Blood Pressure medications (value 1) or not (value 0)</li>
#             <li>prevalentStroke: Whether the patient already had at least a stroke (value 1) or not (value 0)</li>
#             <li>prevalentHyp: Whether the patient is hypertensive (value 1) or not (value 0)</li>
#             <li>diabetes: Whether the patient has diabetes (value 1) or not (value 0)</li>
#         </ul>
#     </li>
#     <li>Current Medical Status of the patient
#         <ul>
#             <li>totChol: Float number of the cholesterol measured as mg/dL</li>
#             <li>sysBP: Float number of the systolic blood pressure measured as mmHg</li>
#             <li>diaBP: Float number of the diastolic blood pressure measured as mmHg</li>
#             <li>BMI: Body Mass Index (weight/height$^{2}$) of the patient measured as kg/mt$^{2}$. It is a float number</li>
#             <li>heartRate: Beats/Minute. It is an integer number</li>
#             <li>glucose: Float number of the quantity of glucose in the patient's blood. Measured as mg/dL</li>
#         </ul>
#     </li>
# </ol>
#
#
# <p>As we said, this dataset is labeled. The column's name is TenYearCHD. There are two classes:</p>
#
# <ol>
#     <li>Class 0: The patient won't have a CHD disease in 10 years.</li>
#     <li>Class 1: The patient will have at laest one CHD disease in 10 years.</li>
# </ol>

# %% [markdown]
# <h1>2 Requirements</h1>

# %% [markdown]
# <h2>2.1 Python modules</h2>

# %% [markdown]
# <p>To be able to run this code you will need to install the following modules:</p>
#
# <ol>
#     <li>numpy</li>
#     <li>pandas</li>
#     <li>matplotlib</li>
#     <li>scipy</li>
#     <li>seaborn</li>
#     <li>statsmodels</li>
#     <li>imbalanced-learn</li>
# </ol>
#
# <p>To install them you can either use the conda install command or pip.</p>

# %%
# %%bash
#
#
# conda install -c anaconda numpy pandas matplotlib scipy seaborn statsmodels
# conda install -c conda-forge imbalanced-learn

# %% [markdown]
# <p>This is the command to run if you want to use pip.</p>

# %%
# %%bash
#
# pip install numpy pandas matplotlib seaborn statsmodels imbalanced-learn

# %% [markdown]
# <h2>2.2 Download the dataset</h2>

# %% [markdown]
# <p>The dataset is inside the "./dataset" folder so it is not needed to download it. Anyway, if it would get any updates (it is unlikely since last update was 4 years ago) it is possible to retrieve it from this <a hred="https://www.kaggle.com/amanajmera1/framingham-heart-study-dataset/download">link</a>.</p>

# %% [markdown]
# <h2>2.3 Import all the libraries</h2>

# %% [markdown]
# <p>To avoid forgetting to import libraries, it is suggested to load all of them at once before going any further with the report.</p>

# %%
import math
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from operator import itemgetter
from statsmodels.formula.api import ols

# SCIPY
import scipy.stats as stats
from scipy.stats import pearsonr
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
from scipy.stats import zscore

# SKLEARN
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, mean_squared_error, mean_absolute_error, roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# STATSMODELS
from statsmodels.graphics.gofplots import qqplot

# DATASET BALANCING
from imblearn.over_sampling import SMOTE
from collections import Counter

# LOGISTIC REGRESSION
from statsmodels.formula.api import logit

# MAP NAIVE BAYES
from sklearn.naive_bayes import GaussianNB

# K-NN
from sklearn.neighbors import KNeighborsClassifier as KNN

# RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier

# ADA BOOST
from sklearn.ensemble import AdaBoostClassifier

seed = 123
np.random.seed(seed)

# %% [markdown]
# <h1>3 Data Analysis and Data Refactor</h1>

# %% [markdown]
# <p>In this section the focus is all on the data:</p>
#
# <ul>
#     <li>Is it required to refactor them?</li>
#     <li>Are values from all the columns meaningful?</li>
#     <li>What to do with NaN values?</li>
# </ul>
#
# <p>Data will be first refactored to make it easier to study them and handle any uncompleted records.</p>

# %% [markdown]
# <h2>3.1 Load the dataset</h2>

# %% [markdown]
# <p>As first thing it is needed to load the dataset. Using the "info" method it is possible to have a look at the big picture and to understand the data a little bit more.</p>

# %%
framingham=pd.read_csv('dataset/framingham.csv')

# %% [markdown]
# <h2>3.2 Data quality assessment</h2>

# %%
framingham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %% [markdown]
# <p>The first column is called "male". It would be less confusing to call it "sex". It is probably better to use numbers instead of words as values for this column, so it will keep the same logic as discussed in section 1.2 About the dataset: 0 for females and 1 for males.</p>
#
# <p>Here the operations block meant to change the name of the column "male" in "sex".</p>

# %%
framingham.columns = [col if col != 'male' else 'sex' for col in framingham]

# %% [markdown]
# <p><b>QUESTION: Are four classes for education really needed?</b></p>
#
# <p>It is not needed to have four classes for education because three of them would be enough for this case. The reason about this conclusion is that class 2 and class 3 are redundant. For the records, class 2 means that the patient has an High School degree, meanwhile class 3 means that the patient tried to get a college degree, but he or she finally hasn't get it yet. So, class 2 and class 3 are grouped together in class 2 and class 4 (which is patients with a college degree) is relabeled as class 3.</p>

# %%
framingham['education'] = framingham['education'].fillna(1)
framingham['education'] = framingham['education'].replace({3:2})
framingham['education'] = framingham['education'].replace({4:3})
framingham['education'].describe()
# Out:
# count    4240.000000
# mean        1.681132
# std         0.663633
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         3.000000
# Name: education, dtype: float64

# %% [markdown]
# <p><b>QUESTION: What to do with NaN values?</b></p>
#
# <p>The biggest problem is related with the NaN values of the column "glucose" because it is an important value. The easiest thing to do would be to use the mean value, but it is possible to find a way to get these values with linear regretion. Given the fact that the "glucose" columns holds a very important data and that 400 records are around 8%/10% of the number of the records, it is probably a good idea to just drop the records with NaN values.</p>
#
# <p>Lastly, six columns with NaN values remains, but the total number of records with NaN values for these columns are not so many. The strategy to adopt for these columns is the following:</p>
#
# <ul>
#     <li>For education, NaN values are replaced with "1" which is the lowest value/class</li>
#     <li>For cigsPerDay, NaN values are replaced with "0" if the patient is not a smoker, or the mean value if he or she is a smoker</li>
#     <li>For BPMeds/totChol/BMI/heartRate it will be the mean value</li>
# </ul>

# %%
framingham['BPMeds'] = framingham['BPMeds'].fillna(-1)
framingham['totChol'] = framingham['totChol'].fillna(-1)
framingham['BMI'] = framingham['BMI'].fillna(-1)
framingham['heartRate'] = framingham['heartRate'].fillna(-1)
framingham['BPMeds'] = framingham['BPMeds'].replace({-1:2})
framingham['totChol'] = framingham['totChol'].replace({-1:2})
framingham['BMI'] = framingham['BMI'].replace({-1:2})
framingham['heartRate'] = framingham['heartRate'].replace({-1:2})

# %%
framingham = framingham.dropna()

# %% [markdown]
# <h1>4 Descriptive statistics on the data</h1>

# %% [markdown]
# <p>In this section, statistical methods will be used to study the data and to try snatching from them as many information as possible.</p>

# %% [markdown]
# <h2>4.1 Data distribution</h2>

# %%
framingham.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3827 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sex              3827 non-null   int64
#  1   age              3827 non-null   int64
#  2   education        3827 non-null   float64
#  3   currentSmoker    3827 non-null   int64
#  4   cigsPerDay       3827 non-null   float64
#  5   BPMeds           3827 non-null   float64
#  6   prevalentStroke  3827 non-null   int64
#  7   prevalentHyp     3827 non-null   int64
#  8   diabetes         3827 non-null   int64
#  9   totChol          3827 non-null   float64
#  10  sysBP            3827 non-null   float64
#  11  diaBP            3827 non-null   float64
#  12  BMI              3827 non-null   float64
#  13  heartRate        3827 non-null   float64
#  14  glucose          3827 non-null   float64
#  15  TenYearCHD       3827 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %% [markdown]
# <p>After filling/dropping NaN values, the dataset lost around 500 records. It is still acceptable, and it will be proved later on.</p>

# %% [markdown]
# <h3>4.1.1 CHD in 10 years</h3>

# %% [markdown]
# <p>This is a dataset created to perform classification tasks. The column which holds the labels is "TenYearCHD" which means if the patient will suffer a CHD in ten years.</p>
#
# <p>In this section it will be given an answer to the following question:</p>
#
# <ul>
#     <li>Is the dataset balanced?</li>
# </ul>

# %%
plt.figure(figsize=(16,6))
plt.title('Will the patient suffer a CHD in ten years?')
counts = framingham['TenYearCHD'].value_counts()
plt.bar(["False","True"],counts)
plt.grid()

# %% [markdown]
# <p>As the plot shows, this dataset is unbalanced. It is clearly shown that for each person that will have a CHD in ten years there are about 6/7 who won't. Obviously, this can be a problem, because unbalanced datasets might not work with many algorithms (and generally they perform worse with unbalanced data). This will be addressed in section 5, by performing data balancing before going on with the classification task.</p>

# %% [markdown]
# <h3>4.1.2 Sex and Age</h3>

# %% [markdown]
# <p>In this section, it will be put a focus on sex and age distributions.</p>
#
# <p>Questions related to this section are:</p>
#
# <ul>
#     <li>Are there more female or male in the dataset?</li>
#     <li>What is the distribution of ages of the dataset?</li>
#     <li>And what about the distribution of ages of persons who will suffer a CHD?</li>
#     <li>Are distribution of male and female alike?</li>
# </ul>

# %%
plt.figure(figsize=(16,6))
plt.title('Sex')
counts = framingham['sex'].value_counts()
plt.bar(["Female", "Male"],counts)
plt.grid()

# %% [markdown]
# <p>The female population of the dataset is higher slightly of the male population.</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Patients\' age in the dataset')
counts = framingham['age'].value_counts().sort_index(ascending=False).plot.bar()
plt.grid()

# %% [markdown]
# <p>The distribution of the patients' age is almost a gaussian: given a record from the dataset, the probability that it is of a very old person or a very young person is low.</p>
#
# <p>Futhermore, this graphs tells another story: younger persons care of their health regarding CHDs. It is clear that CHDs are not only a problem concerning old persons, but it can depend from many different things and no one should underestimate this danger.</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Age of patients with a CHD in ten years')
counts = (framingham[framingham['TenYearCHD']==1])['age'].value_counts().sort_index(ascending=False).plot.bar()
plt.grid()

# %% [markdown]
# <p>This graph shows the age distribution of patients who will suffer of a CHD in 10 years (with no treatments).</p>
#
# <p>As obvious as it is, older persons are more in danger and they will suffer of a CHD more likely than younger persons. But this graphs shows that younger people must not underestimate their health care.</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Distribution of patients\' age')
cdf_all = framingham['age'].value_counts(normalize=True).sort_index(ascending=True).cumsum()
cdf_chd = (framingham[framingham['TenYearCHD']==1])['age'].value_counts(normalize=True).sort_index(ascending=True).cumsum()
plt.plot(cdf_all.index, cdf_all.values)
plt.plot(cdf_chd.index, cdf_chd.values)
plt.legend(["Age of all patients", "Age of patients with CHD in 10 years"])
plt.grid()

# %% [markdown]
# <p>The reason behind this graph was to show if the distribution of age of the dataset was similar to the distribution of the age of persons who will suffer a CHD in 10 year. It is clear that it is not the case: among persons who will have a CHD in 10 years, the majority is older than 50/55 years old. This won't surely surprise the reader, but it was still worth pointing out.</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Sex')
cdf_male = (framingham[framingham['sex']==1])['age'].value_counts(normalize=True).sort_index().cumsum()
cdf_female = (framingham[framingham['sex']==0])['age'].value_counts(normalize=True).sort_index().cumsum()
plt.plot(cdf_female.index, cdf_female.values)
plt.plot(cdf_male.index, cdf_male.values)
plt.legend(["Female", "Male"])
plt.grid()

# %% [markdown]
# <p>Distribution of age of persons in the dataset grouped by sex are similar. This is important, because it won't happen that a bias related to the sex of the patient can be introduced when proceding with classification tasks (or at least it will be less likely).</p>

# %% [markdown]
# <h3>4.1.3 Smokers</h3>

# %% [markdown]
# <p>Smokers are clearly more likely to suffer a CHD in their future, so it could be worth to study the data distribution of smokers (number of cigarettes, sex...). However, it is a lot interesting and fascinating the possibility to check if there exists any relations with being a smoker with other features. For instance, it could be interesting to see if being a smoker is related to the level of education or to the age. To clearify, it is not a relationship meant as correlation, but just a comparation with graphs.</p>
#
# <p>It could be worth to recall the education feature for the reader. Patients in the dataset may have three different education labels, depending on whether they have an high school degree or not, or if they have a college degree.</p>
#
# <p>It will be given an answer to the following questions:</p>
#
# <ul>
#     <li>How many smokers are there in the dataset?</li>
#     <li>Do men smoke more than women?</li>
#     <li>Can the level of education give information about the smokers?</li>
# </ul>

# %%
plt.figure(figsize=(16,6))
plt.title('Smokers')
counts = framingham['currentSmoker'].value_counts()
plt.bar(["Not a smoker", "Smoker"],counts)
plt.grid()

# %%
# Number of cigarettes smoked per day
counts = [0,0,0,0]

# Create 4 bins with width of 20
counts[0]=len((framingham[framingham['cigsPerDay']<20]))
counts[1]=len(framingham[(framingham['cigsPerDay']>=20)&(framingham['cigsPerDay']<40)])  
counts[2]=len(framingham[(framingham['cigsPerDay']>40)&(framingham['cigsPerDay']<60)])  
counts[3]=len(framingham[(framingham['cigsPerDay']>60)])


plt.figure(figsize=(16,8))
plt.title('Cigarettes smoked per day')
plt.pie(counts, labels=['Less than 20','From 20 to 40','From 40 to 60','More than 60'])
plt.show()


# Create scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(framingham['cigsPerDay'], framingham['age'], hue=framingham['sex'])
plt.show()
# Out:
# /home/mc/anaconda3/envs/fad/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <p>Among the dataset smokers are the majority, but not by far. It is almost a 50%-50% scenario. In any case, the majority of the patients smoke less than 20 cigarettes. It could be possible to say that almost all the patients smoke less than 40 cigarettes a day. Only a couple of them smoke more than 40 ("luckily", someone would say).</p>
#
# <p>The scatterplot shows the distribution of smokers filtered by sex (0 female, 1 male). It shows clearly that men tend to smoke more cigarettes per day than females (or at least it is what happens with people from this dataset).</p>

# %%
# Smokers/No-Smokers who are male
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.title('Males')
(framingham[framingham['sex']==1]).groupby('currentSmoker')['currentSmoker'].value_counts().plot.pie(labels=["Not a smoker","Smoker"])

# Smokers/No-Smokers who are female
plt.subplot(1,3,2)
plt.title('Females')
(framingham[framingham['sex']==0]).groupby('currentSmoker')['currentSmoker'].value_counts().plot.pie(labels=["Not a smoker","Smoker"])

# Smokers/No-Smokers by age

# Number of smokers grouped by age
counts = [0,0,0,0]

# Create 4 bins with width of 20
counts[0]=len(framingham[(framingham['currentSmoker']==1)&(framingham['age']<40)])
counts[1]=len(framingham[(framingham['currentSmoker']==1)&(framingham['age']>=40)&(framingham['age']<50)])  
counts[2]=len(framingham[(framingham['currentSmoker']==1)&(framingham['age']>=50)&(framingham['age']<60)])  
counts[3]=len(framingham[(framingham['currentSmoker']==1)&(framingham['age']>=60)])
                                                        
                                                        
plt.subplot(1,3,3)
plt.title('Ages')
plt.pie(counts, labels=['Younger than 40 y','From 40 to 50 years','From 50 to 60 years','Older than 60'])
plt.show()

# %% [markdown]
# <p>These graphs show an interesting fact: males smoke more than females. If someone would like to speculate on it, It would be possible to say that a reason behind this could be cultural habits. For instance, in the past in many countries smoking was a sign to have become an adult man. In anycase, this report wants to be as much precise as possible so the previous sentence must not be taken as the only reason for this difference, but it can be a clear example of why cultural habits can explain it. Futhermore, this observation could be true only for this specific dataset.</p>
#
# <p>Older people tend to smoke more than younger people. It is interesting to see that almost 50% of the smokers are 40/50 years old.</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Level of Education')
counts = framingham['education'].value_counts()
plt.bar(["1", "2", "3"],counts)
plt.grid()

# %%
# Smokers/No-Smokers with no high school degress
plt.figure(figsize=(12,6))
plt.subplot(1,3,1)
plt.title('No Degrees')
(framingham[framingham['education']==1]).groupby('currentSmoker')['currentSmoker'].value_counts().plot.pie(labels=["Not a smoker","Smoker"])

# Smokers/No-Smokers with an high school degress
plt.subplot(1,3,2)
plt.title('High School Degrees')
(framingham[framingham['education']==2]).groupby('currentSmoker')['currentSmoker'].value_counts().plot.pie(labels=["Not a smoker","Smoker"])

# Smokers/No-Smokers with a college degress
plt.subplot(1,3,3)
plt.title('College Degrees')
(framingham[framingham['education']==3]).groupby('currentSmoker')['currentSmoker'].value_counts().plot.pie(labels=["Not a smoker","Smoker"])
plt.show()

# %% [markdown]
# <p>Differently from the sex and the age, education doesn't seem so related with being a smoker in this dataset.</p>

# %% [markdown]
# <h2>4.2 Boxplot</h2>

# %%
plt.figure(figsize=(20,16))

columns = ['cigsPerDay', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose']
j=1
for i in columns:
    plt.subplot(2,4,j)
    j+=1
    plt.title(i)
    x=framingham[i]
    plt.boxplot(x)
    plt.grid()
plt.show()

# %% [markdown]
# <p>Used to study data distribution inside the dataset, boxplots are useful to get a lof of information of the data for specific columns of DataFrames. For instance it is easy to notice if there are outliers for a specific column.</p>
#
# <p>Speaking of the Framingham dataset, most of the the columns are booleans so they don't carry a lot of interesting information. There is something worth to notice: the data of columns where the values are real numbers (totChol, sysBP, diaBP, BMI, heartRate, glucose) are consistent with what doctors say that "safe" values would be. Infact the "safe" values are something like:</p>
#
# <ul>
#     <li>Cholesterol: from 50 to 200</li>
#     <li>Systolic BP: from 65 to 90</li>
#     <li>Diastolic BP: from 70 to 130</li>
#     <li>BMI: from 18 to 25</li>
#     <li>Heart Rate: from 55 to 110</li>
#     <li>Glucose: 60 to 110</li>
# </ul>
#
# <p>Most of the columns respect these values (or include them inside the first and the third quartile), except for the totChol that is very high: those values (200+) can be dangerous for the health of the patients.</p>

# %%
framingham.describe()
# Out:
#                sex          age    education  currentSmoker   cigsPerDay  \
# count  3827.000000  3827.000000  3827.000000    3827.000000  3827.000000
# mean      0.442383    49.642017     1.679383       0.487327     8.981448
# std       0.496734     8.608575     0.665717       0.499905    11.914705
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    57.000000     2.000000       1.000000    20.000000
# max       1.000000    70.000000     3.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  3827.000000      3827.000000   3827.000000  3827.000000  3827.000000
# mean      0.056441         0.006271      0.313300     0.027437   236.302064
# std       0.282717         0.078953      0.463896     0.163373    46.256548
# ...

# %% [markdown]
# <p>The description of the DataFrame confirm what it was said: there aren't a lot of outliers and mean values for some of these values (such as totChol) are higher than expected.</p>

# %% [markdown]
# <h2>4.3 Skewness and Kurtosis</h2>

# %%
plt.figure(figsize=(20,16))

columns = ['cigsPerDay', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose']
j=1
for i in columns:
    plt.subplot(3,3,j)
    j+=1
    plt.title(i)
    x=framingham[i]
    x.plot.density()
    plt.grid()
plt.show()
#indici di forma
print("SKEWNESS")
print(framingham.skew(),"\n\n\n")
print("KURTOSIS")
print(framingham.kurtosis())
# Out:
# SKEWNESS
# sex                 0.232104
# age                 0.223339
# education           0.469814
# currentSmoker       0.050729
# cigsPerDay          1.241410
# BPMeds              5.433621
# prevalentStroke    12.513488
# prevalentHyp        0.805342
# diabetes            5.788099
# totChol             0.510808
# sysBP               1.161437
# diaBP               0.716014
# BMI                 0.266243
# heartRate           0.594958
# glucose             6.220160
# TenYearCHD          2.206456
# dtype: float64
#
#
#
# KURTOSIS
# sex                 -1.947145
# age                 -1.000473
# education           -0.759815
# currentSmoker       -1.998471
# cigsPerDay           1.006914
# BPMeds              30.520377
# prevalentStroke    154.668213
# prevalentHyp        -1.352132
# diabetes            31.518561
# totChol              5.251010
# sysBP                2.253075
# diaBP                1.280760
# BMI                  4.977567
# heartRate            1.342147
# ...

# %% [markdown]
# <p>For all the columns where the values are real number (cigsPerDay, totChol, sysBP, diaBP, BMI, heartRate, glucose) it is possible to see that their estimated density graphs are all leptokurtic. Most of them have positive skew.</p>

# %% [markdown]
# <h2>4.4 Q-Q Plots</h2>

# %% [markdown]
# <p>Q-Q Plots are useful graphs used to understand whether a group of data follows a gaussian distribution.</p>
#
# <p>Since it will be needed to know if the variables (aka columns) in this dataset are approximately distributed as a gaussian for MAP, Q-Q plots will be generated from the not-boolean columns.</p>

# %%
preprocessing.normalize(framingham)
# Out:
# array([[0.0038139 , 0.14874192, 0.01144169, ..., 0.30511162, 0.29366994,
#         0.        ],
#        [0.        , 0.14442261, 0.00627924, ..., 0.2982641 , 0.23861128,
#         0.        ],
#        [0.00321817, 0.15447236, 0.00321817, ..., 0.24136306, 0.22527219,
#         0.00321817],
#        ...,
#        [0.        , 0.15132002, 0.00582   , ..., 0.23280003, 0.31137004,
#         0.        ],
#        [0.0036359 , 0.14543593, 0.0072718 , ..., 0.24360518, 0.26178468,
#         0.        ],
#        [0.        , 0.13789511, 0.00707154, ..., 0.30054062, 0.28286176,
#         0.        ]])

# %%
def plot_histogram_and_qq(points, mu, sigma, index):
    # Plot histogram of the 1000 points
    plt.figure(figsize=(12,6))
    ax = plt.subplot(index,2,1)
    count, bins, ignored = plt.hist(points, 30, density=True)
    ax.set_title('Histogram')
    ax.set_xlabel('Value bin')
    ax.set_ylabel('Frequency')

    # Overlay the bell curve (normal distribution) on the bins data
    bell_curve = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2))
    plt.plot(bins, bell_curve, linewidth=2, color='r')

    # Q-Q plot
    plt.subplot(index,2,2)
    res = stats.probplot(zscore(points), dist="norm", plot=plt)

    plt.show()

# %%
columns = ['cigsPerDay', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate', 'glucose']
i = 1

for column in columns:
    print("\n\n Column: {}".format(column.capitalize()))
    mu = framingham[column].mean()
    sigma = framingham[column].std()
    plot_histogram_and_qq(framingham[column], mu, sigma, i)
    i+=1
# Out:
#  Column: Cigsperday
#  Column: Totchol
#  Column: Sysbp
#  Column: Diabp
#  Column: Bmi
#  Column: Heartrate
#  Column: Glucose

# %% [markdown]
# <p>It is possible to notice that they all follow approximately a gaustrian distribution (except for Cigsperday).</p>

# %% [markdown]
# <h2>4.5 Linear Regression</h2>

# %% [markdown]
# <p>In this section it will be used the linear regression to seek for columns that have high correlation: this will allow to forecast values of a specific column based on values of another columns.</p>

# %%
columns = framingham.columns
corr_arr= []

# PEARSON
for i in range(len(columns)):
    for j in range(i,len(columns)):
        if i!=j:
            corr_arr.append([columns[i], columns[j], \
                             pearsonr(framingham[columns[i]],framingham[columns[j]])[0], \
                             spearmanr(framingham[columns[i]],framingham[columns[j]])[0], \
                             kendalltau(framingham[columns[i]],framingham[columns[j]])[0]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 columns = framingham.columns
#       2 corr_arr= []
#       4 # PEARSON
#
# NameError: name 'framingham' is not defined

# %%
def print_correlations(data):
    for el in data:
        print("{} and {}: {:.2f}".format(el[0], el[1], el[2]))

corr_arr = sorted(corr_arr, key=itemgetter(2))
pearson_getter = itemgetter(0, 1, 2) 
pearsons = list(map(list, map(pearson_getter, corr_arr)))

print("PEARSON\n")

print("5 most inversely correlated")
print_correlations(pearsons[0:5])
print("\n\n")
print("5 most directly correlated")
pearsons.reverse()
print_correlations(pearsons[0:5])
print("\n\n")

corr_arr = sorted(corr_arr, key=itemgetter(3))
spearman_getter = itemgetter(0, 1, 3) 
spearmans = list(map(list, map(spearman_getter, corr_arr)))

print("SPEARMAN\n")

print("5 most inversely correlated")
print_correlations(spearmans[0:5])
print("\n\n")
print("5 most directly correlated")
spearmans.reverse()
print_correlations(spearmans[0:5])
print("\n\n")

corr_arr = sorted(corr_arr, key=itemgetter(4))
kendall_getter = itemgetter(0, 1, 4) 
kendall = list(map(list, map(kendall_getter, corr_arr)))

print("KENDALL\n")

print("5 most inversely correlated")
print_correlations(kendall[0:5])
print("\n\n")
print("5 most directly correlated")
kendall.reverse()
print_correlations(kendall[0:5])
print("\n\n")
# Out:
# PEARSON
#
# 5 most inversely correlated
# age and currentSmoker: -0.21
# age and education: -0.20
# age and cigsPerDay: -0.19
# currentSmoker and BMI: -0.15
# education and BMI: -0.14
#
#
#
# 5 most directly correlated
# sysBP and diaBP: 0.78
# currentSmoker and cigsPerDay: 0.77
# prevalentHyp and sysBP: 0.70
# diabetes and glucose: 0.62
# prevalentHyp and diaBP: 0.62
#
#
#
# SPEARMAN
#
# 5 most inversely correlated
# age and cigsPerDay: -0.21
# age and education: -0.21
# age and currentSmoker: -0.21
# currentSmoker and BMI: -0.17
# education and BMI: -0.15
#
#
#
# 5 most directly correlated
# currentSmoker and cigsPerDay: 0.93
# sysBP and diaBP: 0.78
# prevalentHyp and sysBP: 0.70
# prevalentHyp and diaBP: 0.62
# age and sysBP: 0.39
#
#
#
# KENDALL
#
# 5 most inversely correlated
# age and currentSmoker: -0.17
# age and education: -0.17
# age and cigsPerDay: -0.16
# currentSmoker and BMI: -0.14
# education and BMI: -0.12
#
#
#
# 5 most directly correlated
# ...

# %% [markdown]
# <p>It is clearly shown that there aren't so many columns correlated (either directly or inversely). Most of the correlated columns are "naive" ones: for instance, an high number of smoked cigarettes leads to the patient being a smoker, or an high quantity of systolic blood pressure leads to the patient being hypertensive.</p>

# %%
plt.title("pearson")
sns.heatmap(framingham.corr())
plt.show()

plt.title("spearman")
sns.heatmap(framingham.corr(method='spearman'))
plt.show()

plt.title("kendall")
sns.heatmap(framingham.corr(method='kendall'))
plt.show()

# %% [markdown]
# <p>The heatmaps confirm what was said in the previous paragraph.</p>
#
# <p>Is there any couple of columns that can be used with linear regression? The following piece of code will try to seek for them.</p>

# %%
# For each couple of columns, it will compute the R^2
# value 

columns = framingham.columns
for i in range(len(columns)):
    for j in range(i,len(columns)):
        if i!= j:
            t="{} ~ {} ".format(columns[i], columns[j])
            model = ols(t,framingham).fit()
            if model.rsquared>0.5:
                print("\n\n{} and {}:".format(columns[i], columns[j]))
                print(model.params)
                sns.regplot(columns[i], columns[j], framingham)
                plt.show()
                print(model.summary())
                print("\n\n")
            else:
                print('{} ~ {}: R^2 is too low.'.format(columns[i], columns[j]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # For each couple of columns, it will compute the R^2
#       2 # value
# ----> 4 columns = framingham.columns
#       5 for i in range(len(columns)):
#       6     for j in range(i,len(columns)):
#
# NameError: name 'framingham' is not defined

# %% [markdown]
# <p>Most of the columns are not strong enough to be used to forecast values for the other ones. Just two couple of columns have a value for the $R^2$ parameter higher than 0.5:</p>
#
# <ul>
#     <li>currentSmoker and cigsPerDay ($R^2$ of 0.598)</li>
#     <li>diaBP and sysBP ($R^2$ of 0.615)</li>
# </ul>
#
# <p>It is possible that a multi-linear regression approach would give better results for other columns. It will be applied for sysBP and diaBP columns (currentSmoker and cigsPerDay it is infact a silly correlation).</p>

# %%
columns = framingham.columns
r_squared = []
for i in range(len(columns)):
    for j in range(len(columns)):
        for z in range(len(columns)):
            if i!= j and j != z and i != z:
                t="{} ~ {}+{}".format(columns[i], columns[j], columns[z])
                model = ols(t,framingham).fit()
                if model.rsquared>0.6:
                    r_squared.append([columns[i], columns[j], columns[z], model.rsquared])

# %%
def print_r_squared(data):
    for el in data:
        print("{} from {} and {}:".format(el[0], el[1], el[2]), "R-squared: ", el[3])

# %%
r_squared_sorted = sorted(r_squared, key=itemgetter(3), reverse=True)
print_r_squared(r_squared_sorted[0:20:2]) #r-square values are duplicated
# Out:
# sysBP from prevalentHyp and diaBP: R-squared:  0.6901061151644203
# sysBP from diaBP and age: R-squared:  0.6704093618687624
# diaBP from sysBP and BMI: R-squared:  0.6312520222226206
# cigsPerDay from sex and currentSmoker: R-squared:  0.6272558830076688
# diaBP from age and sysBP: R-squared:  0.6269338631993555
# diaBP from sysBP and prevalentHyp: R-squared:  0.6235427424829929
# sysBP from glucose and diaBP: R-squared:  0.6233433855635441
# diaBP from sex and sysBP: R-squared:  0.6226854191303708
# sysBP from diaBP and sex: R-squared:  0.6222813200174839
# sysBP from BPMeds and diaBP: R-squared:  0.622005098477723

# %% [markdown]
# <p>It seems that sysBP could be forecasted from a couple of different columns (and not just diaBP). It could be worth to check if the $R^2$ value would increase considering the following columns:</p>
#
# <ul>
#     <li>prevalentHyp</li>
#     <li>age</li>
#     <li>TenYearCHD</li>
#     <li>glucose</li>
# </ul>

# %%
print('\n\nCombination of two:')
columns = 'sysBP ~ prevalentHyp+diaBP+age'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ prevalentHyp+diaBP+TenYearCHD'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ prevalentHyp+diaBP+glucose'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ TenYearCHD+diaBP+age'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ TenYearCHD+diaBP+glucose'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ glucose+diaBP+age'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))

print('\n\nCombination of three:')
columns = 'sysBP ~ prevalentHyp+diaBP+age+TenYearCHD'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ prevalentHyp+diaBP+TenYearCHD+glucose'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))
columns = 'sysBP ~ prevalentHyp+diaBP+glucose+age'
print('{}. R-square: {}'.format(columns,ols(columns,framingham).fit().rsquared))

print('\n\nAll four of them:')
print(ols('sysBP ~ prevalentHyp+diaBP+glucose+age+TenYearCHD',framingham).fit().rsquared)
# Out:
# Combination of two:
# sysBP ~ prevalentHyp+diaBP+age. R-square: 0.7210450195400386
# sysBP ~ prevalentHyp+diaBP+TenYearCHD. R-square: 0.6918726722970399
# sysBP ~ prevalentHyp+diaBP+glucose. R-square: 0.6958722593122291
# sysBP ~ TenYearCHD+diaBP+age. R-square: 0.6720558350925913
# sysBP ~ TenYearCHD+diaBP+glucose. R-square: 0.6274505523683844
# sysBP ~ glucose+diaBP+age. R-square: 0.6749375820952
#
#
# Combination of three:
# sysBP ~ prevalentHyp+diaBP+age+TenYearCHD. R-square: 0.7216963287765245
# sysBP ~ prevalentHyp+diaBP+TenYearCHD+glucose. R-square: 0.6974751882460172
# sysBP ~ prevalentHyp+diaBP+glucose+age. R-square: 0.7245023122450793
#
#
# All four of them:
# 0.7251030873018761

# %% [markdown]
# <p>The highest $R^2$ values are for these four combinations:</p>
#
# <ul>
#     <li>0.721 - prevalentHyp, diaBP, age</li>
#     <li>0.723 - prevalentHyp, diaBP, age, TenYearCHD</li>
#     <li>0.725 - prevalentHyp, diaBP, glucose, age</li>
#     <li>0.726 - prevalentHyp, diaBP, glucose, age, TenYearCHD</li>
# </ul>
#
#
# <p>All these combinations could be used to forecast values for sysBP. Anyway, the $R^2$ values are not that high to justify adding more columns (which makes the model more complicated). So it is probably just enough to use the values of prevalentHyp and diaBP to forecast sysBP (since that model has a value for $R^2$ of 0.69, which is lower than just 0.03 percentage). </p>

# %%
model = ols('sysBP ~ prevalentHyp+diaBP',framingham).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sysBP   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     4258.
# Date:                Mon, 26 Jul 2021   Prob (F-statistic):               0.00
# Time:                        16:31:09   Log-Likelihood:                -15044.
# No. Observations:                3827   AIC:                         3.009e+04
# Df Residuals:                    3824   BIC:                         3.011e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# <h1>5 Classification</h1>

# %% [markdown]
# <p>In this section there will be an in-depth evaluation of possible approaches to apply classification methods to answer the main question: "<b><i>Will the patient have a CHD in ten years?</i></b>"</p>

# %% [markdown]
# <h2>5.1 Framingham risk score</h2>

# %% [markdown]
# <p>Although it is not a classification method, it was interesting to talk about the Framingham Risk Score, which has the same goal as the classification for this specific dataset.</p>
#
# <p>The Framingham Risk Score (FRS from now on) $^[$$^1$$^]$ is one of a number of scoring systems used to determine an individual's chances of developing cardiovascular disease. Cardiovascular risk scoring systems give an estimate of the probability that a person will develop cardiovascular disease within a specified amount of time, usually 10 to 30 years.</p>
#
# <p>Because they give an indication of the risk of developing cardiovascular disease, they also indicate who is most likely to benefit from prevention. For this reason, cardiovascular risk scores are used to determine who should be offered preventive drugs such as drugs to lower blood pressure and drugs to lower cholesterol levels.</p>

# %%
def compute_frs(patient_data):
    if patient_data['sex'] == 0:
        return frs_woman(patient_data)
    else:
        return frs_man(patient_data)

def frs_woman(patient_data):
    points = 0
    
    # age is a risk factor
    if 20 <= patient_data['age'] < 35:
        points = points - 7
    elif 35 <= patient_data['age'] < 40:
        points = points - 3
    elif 40 <= patient_data['age'] < 45:
        points = points
    elif 45 <= patient_data['age'] < 50:
        points = points + 3
    elif 50 <= patient_data['age'] < 55:
        points = points + 6
    elif 55 <= patient_data['age'] < 60:
        points = points + 8
    elif 60 <= patient_data['age'] < 65:
        points = points + 10
    elif 65 <= patient_data['age'] < 70:
        points = points + 12
    elif 70 <= patient_data['age'] < 75:
        points = points + 14
    elif patient_data['age'] >= 75:
        points = points + 16
        
    #total cholesterol is a risk factor
    if 20 <= patient_data['age'] < 40:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 4
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 8
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 11
        elif patient_data['totChol'] >= 280:
            points = points + 13
            
    elif 40 <= patient_data['age'] < 50:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 3
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 6
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 8
        elif patient_data['totChol'] >= 280:
            points = points + 10
            
    elif 50 <= patient_data['age'] < 60:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 2
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 4
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 5
        elif patient_data['totChol'] >= 280:
            points = points + 7
            
    elif 60 <= patient_data['age'] < 70:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 1
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 2
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 3
        elif patient_data['totChol'] >= 280:
            points = points + 4
            
    elif patient_data['age'] >= 70:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 1
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 1
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 2
        elif patient_data['totChol'] >= 280:
            points = points + 2
            
            
    #being a smoker is a risk factor
    if patient_data['currentSmoker'] > 0:
        if 24 <= patient_data['age'] < 40:
            points = points + 9
        elif 40 <= patient_data['age'] < 50:
            points = points + 7
        elif 50 <= patient_data['age'] < 60:
            points = points + 4
        elif 60 <= patient_data['age'] < 70:
            points = points + 2
        elif patient_data['age'] >= 70:
            points = points + 1
            
    #systolic blood pressure is a risk factor
    if patient_data['BPMeds'] > 0:
        if patient_data['sysBP'] < 120:
            points = points
        elif 120 <= patient_data['sysBP'] < 130:
            points = points + 3
        elif 130 <= patient_data['sysBP'] < 140:
            points = points + 4
        elif 140 <= patient_data['sysBP'] < 160:
            points = points + 5
        elif patient_data['sysBP'] >= 160:
            points = points + 6
        
    else:
        if patient_data['sysBP'] < 120:
            points = points
        elif 120 <= patient_data['sysBP'] < 130:
            points = points + 1
        elif 130 <= patient_data['sysBP'] < 140:
            points = points + 2
        elif 140 <= patient_data['sysBP'] < 160:
            points = points + 3
        elif patient_data['sysBP'] >= 160:
            points = points + 4
            
    if points < 9:
        return 0
    elif 9 <= points <= 12:
        return 1
    elif 13 <= points <= 14:
        return 2
    elif points == 15:
        return 3
    elif points == 16:
        return 4
    elif points == 17:
        return 5
    elif points == 18:
        return 6
    elif points == 19:
        return 8
    elif points == 20:
        return 11
    elif points == 21:
        return 14
    elif points == 22:
        return 17
    elif points == 23:
        return 22
    elif points == 24:
        return 27
    elif points >= 25:
        return 30 + 5 * (points - 25)
    
def frs_man(patient_data):
    points = 0
    
    # age is a risk factor
    if 20 <= patient_data['age'] < 35:
        points = points - 9
    elif 35 <= patient_data['age'] < 40:
        points = points - 4
    elif 40 <= patient_data['age'] < 45:
        points = points
    elif 45 <= patient_data['age'] < 50:
        points = points + 3
    elif 50 <= patient_data['age'] < 55:
        points = points + 6
    elif 55 <= patient_data['age'] < 60:
        points = points + 8
    elif 60 <= patient_data['age'] < 65:
        points = points + 10
    elif 65 <= patient_data['age'] < 70:
        points = points + 11
    elif 70 <= patient_data['age'] < 75:
        points = points + 12
    elif patient_data['age'] >= 75:
        points = points + 13
        
    #total cholesterol is a risk factor
    if 20 <= patient_data['age'] < 40:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 4
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 7
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 9
        elif patient_data['totChol'] >= 280:
            points = points + 11
            
    elif 40 <= patient_data['age'] < 50:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 3
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 5
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 6
        elif patient_data['totChol'] >= 280:
            points = points + 8
            
    elif 50 <= patient_data['age'] < 60:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 2
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 3
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 4
        elif patient_data['totChol'] >= 280:
            points = points + 5
            
    elif 60 <= patient_data['age'] < 70:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points + 1
        elif 200 <= patient_data['totChol'] < 240:
            points = points + 1
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 2
        elif patient_data['totChol'] >= 280:
            points = points + 3
            
    elif patient_data['age'] >= 70:
        if patient_data['totChol'] < 160:
            points = points
        elif 160 <= patient_data['totChol'] < 200:
            points = points
        elif 200 <= patient_data['totChol'] < 240:
            points = points
        elif 240 <= patient_data['totChol'] < 280:
            points = points + 1
        elif patient_data['totChol'] >= 280:
            points = points + 1
            
            
    #being a smoker is a risk factor
    if patient_data['currentSmoker'] > 0:
        if 24 <= patient_data['age'] < 40:
            points = points + 8
        elif 40 <= patient_data['age'] < 50:
            points = points + 5
        elif 50 <= patient_data['age'] < 60:
            points = points + 3
        elif 60 <= patient_data['age'] < 70:
            points = points + 1
        elif patient_data['age'] >= 70:
            points = points + 1
            
    #systolic blood pressure is a risk factor
    if patient_data['BPMeds'] > 0:
        if patient_data['sysBP'] < 120:
            points = points
        elif 120 <= patient_data['sysBP'] < 130:
            points = points + 1
        elif 130 <= patient_data['sysBP'] < 140:
            points = points + 2
        elif 140 <= patient_data['sysBP'] < 160:
            points = points + 2
        elif patient_data['sysBP'] >= 160:
            points = points + 3
        
    else:
        if patient_data['sysBP'] < 120:
            points = points
        elif 120 <= patient_data['sysBP'] < 130:
            points = points
        elif 130 <= patient_data['sysBP'] < 140:
            points = points + 1
        elif 140 <= patient_data['sysBP'] < 160:
            points = points + 1
        elif patient_data['sysBP'] >= 160:
            points = points + 2
            
    if points < 1:
        return 0
    elif 1 <= points <= 4:
        return 1
    elif 5 <= points <= 6:
        return 2
    elif points == 7:
        return 3
    elif points == 8:
        return 4
    elif points == 9:
        return 5
    elif points == 10:
        return 6
    elif points == 11:
        return 8
    elif points == 12:
        return 10
    elif points == 13:
        return 12
    elif points == 14:
        return 16
    elif points == 15:
        return 20
    elif points == 16:
        return 25
    elif points >= 17:
        return 30 + 5 * (points - 17)

# %%
print(framingham.iloc[2454])
print("The FRS for the patient is {}%".format(compute_frs(framingham.iloc[2454])))
# Out:
# sex                  1.00
# age                 67.00
# education            1.00
# currentSmoker        1.00
# cigsPerDay          40.00
# BPMeds               0.00
# prevalentStroke      0.00
# prevalentHyp         1.00
# diabetes             0.00
# totChol            216.00
# sysBP              148.00
# diaBP               70.00
# BMI                 32.63
# heartRate           90.00
# glucose            103.00
# TenYearCHD           1.00
# Name: 2718, dtype: float64
# The FRS for the patient is 16%

# %% [markdown]
# <p>This patient will have a probability of 16% to suffer a CHD in 10 years. It matches with what was already known from the column "TenYearCHD". As shown, it is really easy to apply these computations on all the patients' data. The only question is: <b>is it consistent?</b></p>
#
# <p>To show the answer it is necessary to compute it for the whole dataset, adding a column to store the values of the FRS.</p>

# %%
framingham['FRSScore'] = [compute_frs(row) for index, row in framingham.iterrows()]

# %%
# This will show patients' records 
# where TenYearCHD = 1 and where FRSScore is the lowest possible
framingham[framingham['TenYearCHD'] == 1].sort_values('FRSScore', ascending=True).head(10)
# Out:
#       sex  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 2       1   48        1.0              1        20.0     0.0                0
# 2138    1   45        1.0              1         3.0     0.0                0
# 2204    1   52        2.0              1        20.0     0.0                1
# 2221    1   60        1.0              1        30.0     0.0                0
# 2235    1   59        1.0              1        20.0     0.0                0
# 2246    1   50        3.0              1        20.0     0.0                0
# 4232    1   68        1.0              0         0.0     0.0                0
# 2299    1   48        2.0              0         0.0     1.0                0
# 2305    1   66        2.0              1         3.0     0.0                0
# 2319    1   61        1.0              1        13.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %%
# This will show patients' records 
# where TenYearCHD = 0 and where FRSScore is the highest possible
framingham[framingham['TenYearCHD'] == 0].sort_values('FRSScore', ascending=False).head(10)
# Out:
#       sex  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4235    0   48        2.0              1        20.0     2.0                0
# 1002    1   60        1.0              0         0.0     2.0                0
# 3791    1   54        3.0              1        30.0     2.0                0
# 1082    0   49        2.0              1        30.0     0.0                0
# 2393    0   59        2.0              1        15.0     0.0                0
# 1262    0   46        2.0              1        20.0     1.0                0
# 1576    0   46        2.0              1        20.0     0.0                0
# 1572    0   39        2.0              1        20.0     0.0                0
# 1276    0   59        1.0              1        20.0     0.0                0
# 2407    0   49        1.0              1        20.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# ...

# %% [markdown]
# <p>The FRS score is interesting because it can evaluate quickly the probability to suffer a CHD in ten years. As of this dataset, it seems that the TenYearCHD columns is set to 1 for a reasonable high ammount (which should be around 15%).</p>
#
# <p>It is needed to drop this column before moving any further to prevent to influence the classification methods and operations.</p>

# %%
del framingham['FRSScore']

# %% [markdown]
# <h2>5.2 SVM</h2>

# %% [markdown]
# <p>SVM is a binary classificator that computes a decision boundary and classificates records depending on the score they get when they are computed.</p>
#
# <p>SVM comes in different shapes and with different kernels. In this project the kernel used was 'rbf' (Radial Basi Function) which is a gauxian kernel.</p>

# %% [markdown]
# <h3>5.2.1 Fitting the data</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 X_train, X_test, y_train, y_test =\
# ----> 2 train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)
#       3 priint(X_train)
#
# NameError: name 'train_test_split' is not defined

# %%
svm = SVC(kernel='rbf', gamma='auto', C=100, random_state=seed, probability=True)
svm.fit(X_train, y_train)
print("Accuracy sul training set: %0.2f"%svm.score(X_train,y_train))
# Out:
# Accuracy sul training set: 1.00

# %%
y_pred = svm.predict_proba(X_test)[:,1]

fpr_svm_original, tpr_svm_original, threshold_svm_original = roc_curve(y_test, y_pred)

print("SVM\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# SVM
#
# Error: 0.2310283664772663
# MSE: 0.12250636449821932
#
# Confusion Matrix:
# [[985   0]
#  [164   0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       985
#            1       0.00      0.00      0.00       164
#
#     accuracy                           0.86      1149
#    macro avg       0.43      0.50      0.46      1149
# weighted avg       0.73      0.86      0.79      1149
#
# Accuracy
# 0.8572671888598782
# ------------------------------------------------------
# /home/mc/anaconda3/envs/fad/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# <h3>5.2.2 Dataset balancing</h3>

# %% [markdown]
# <p>As stated in section 4.1.1, the dataset is quite <b>unbalanced</b>: there are 6 healthy persons for each patient that will suffer a CHD in ten years.</p>
#
# <p>To address this problem it will be needed a preprocessing phase with the goal of balancing the dataset.</p>

# %% [markdown]
# <h4>5.2.2.1 Undersampling</h4>

# %% [markdown]
# <p>Undersampling is a technique of dataset balancing. To perfom an undersampling means to reduce the number of records in the dataset in order to have all the classes with the same number of records. This doesn't work well in situations where the difference of balance between classes is too high, because it could lead having a dataset with less records than needed raising the danger of underfitting the data during the classification phase.</p>
#
# <p>It will be now shown how to perform undersampling with this dataset using a SVM classifier.</p>

# %%
u_data = framingham[framingham.TenYearCHD==1].copy()
u_data = u_data.append(framingham[framingham.TenYearCHD==0].sample(n=len(framingham[framingham.TenYearCHD==1]), random_state=seed).copy())

# %%
print(u_data.TenYearCHD.value_counts())

plt.figure(figsize=(5,5))
g = sns.countplot(u_data.TenYearCHD)
g.set_xticklabels(['No CHD in ten years', 'CHD in ten years'])
# Out:
# 1    496
# 0    496
# Name: TenYearCHD, dtype: int64
# /home/mc/anaconda3/envs/fad/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'No CHD in ten years'), Text(1, 0, 'CHD in ten years')]

# %%
X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)

# %%
svm = SVC(kernel='rbf', gamma='auto', C=100, random_state=seed, probability=True)
svm.fit(X_train, y_train)
print("Accuracy sul training set: %0.2f"%svm.score(X_train,y_train))
# Out:
# Accuracy sul training set: 1.00

# %%
y_pred_under = svm.predict_proba(X_test)[:,1]

fpr_svm_under, tpr_svm_under, threshold_svm_under = roc_curve(y_test, y_pred_under)

print("SVM\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# SVM
#
# Error: 0.500363396689363
# MSE: 0.25038268574209693
#
# Confusion Matrix:
# [[145   1]
#  [152   0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.49      0.99      0.65       146
#            1       0.00      0.00      0.00       152
#
#     accuracy                           0.49       298
#    macro avg       0.24      0.50      0.33       298
# weighted avg       0.24      0.49      0.32       298
#
# Accuracy
# 0.4865771812080537
# ------------------------------------------------------

# %% [markdown]
# <p>Undersampling is probably not the right choice in this situation: as the logs tell almost all the scores (accuracy, f1-score etc) are low. Futhermore, in this case is possible to notice that the undersampling leads to overfitting (perfect accuracy with the training set, very low accuracy with test set). So, undersampling shouldn't be used with this dataset.</p>

# %% [markdown]
# <h4>5.2.2.2 Oversampling</h4>

# %% [markdown]
# <p>Oversampling means to add new records (duplicating existing one) inside class with few records untill all the classes have the same number of recors.</p>
#
# <p>In this case too, it will be shown how to perform oversampling with the Framingham dataset using a SVM classifier to understand if the results are acceptable.</p>

# %%
o_data = framingham[framingham.TenYearCHD==1].copy()
for i in range(5):
    o_data = o_data.append(framingham[framingham.TenYearCHD==1].copy())

o_data = o_data.append(framingham[framingham.TenYearCHD==0].sample(n=len(o_data[o_data.TenYearCHD==1]), random_state=seed).copy())

# %%
plt.figure(figsize=(5,5))
g = sns.countplot(o_data.TenYearCHD)
g.set_xticklabels(['No CHD in ten years', 'CHD in ten years'])
# Out:
# /home/mc/anaconda3/envs/fad/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0, 0, 'No CHD in ten years'), Text(1, 0, 'CHD in ten years')]

# %%
X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)

# %%
svm = SVC(kernel='rbf', gamma='auto', C=100, random_state=seed, probability=True)
svm.fit(X_train, y_train)
print("Accuracy sul training set: %0.2f"%svm.score(X_train,y_train))
# Out:
# Accuracy sul training set: 1.00

# %%
y_pred_over = svm.predict_proba(X_test)[:,1]

fpr_svm_over, tpr_svm_over, threshold_svm_over = roc_curve(y_test, y_pred_over)

print("SVM\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# SVM
#
# Error: 0.0039396331888220185
# MSE: 3.1456087715662545e-05
#
# Confusion Matrix:
# [[883   0]
#  [  0 903]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       883
#            1       1.00      1.00      1.00       903
#
#     accuracy                           1.00      1786
#    macro avg       1.00      1.00      1.00      1786
# weighted avg       1.00      1.00      1.00      1786
#
# Accuracy
# 1.0
# ------------------------------------------------------

# %% [markdown]
# <p>Results are clearly better than the ones stated in section 5.1.1. The only concern could be that this strategy is that it could be affected by overfitting too. This is possible because the class with less records (class 0) has a fourth of the number of records of class 1. So during oversampling, the algorithm probably duplicated 5 times the same records. Anyway, it doesn't seem the case for this dataset since the accuracy is 1 even for the test set.</p>

# %% [markdown]
# <h4>5.2.2.3 SMOTE</h4>

# %% [markdown]
# <p>SMOTE is an algorithm used to perform oversampling with synthetic data. The most important point is that it duplicates less data in total compared with classic oversampling techniques.</p>
#
# <p>In this case too, it will be used an SVM classifier.</p>

# %%
s_fram = framingham[framingham.TenYearCHD==1].copy()
s_fram= s_fram.append(framingham[framingham.TenYearCHD==0].sample(n=3000, random_state=seed).copy())

# %%
X_resampled, y_resampled = SMOTE(k_neighbors=5, random_state=seed).fit_resample(s_fram.drop('TenYearCHD', axis=1), s_fram.TenYearCHD)
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 3000), (1, 3000)]

# %%
X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)

# %%
svm = SVC(kernel='rbf', gamma='auto', C=100, random_state=seed, probability=True)
svm.fit(X_train, y_train)
print("Accuracy sul training set: %0.2f"%svm.score(X_train,y_train))
# Out:
# Accuracy sul training set: 1.00

# %%
y_pred_svm = svm.predict_proba(X_test)[:,1]

fpr_svm_smote, tpr_svm_smote, threshold_svm_smote = roc_curve(y_test, y_pred_svm)

print("SVM\n")
print("Error:",mean_absolute_error(y_test, y_pred_svm))
print("MSE:",mean_squared_error(y_test, y_pred_svm))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_svm.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_svm.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_svm.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# SVM
#
# Error: 0.10738568240190971
# MSE: 0.08709460053138261
#
# Confusion Matrix:
# [[892   1]
#  [184 723]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91       893
#            1       1.00      0.80      0.89       907
#
#     accuracy                           0.90      1800
#    macro avg       0.91      0.90      0.90      1800
# weighted avg       0.91      0.90      0.90      1800
#
# Accuracy
# 0.8972222222222223
# ------------------------------------------------------

# %%
data_resampled = pd.DataFrame(data= X_resampled, columns=s_fram.drop('TenYearCHD', axis=1).columns)
data_resampled['TenYearCHD']=y_resampled
print('Number of duplicated samples:',\
      len(data_resampled[data_resampled.TenYearCHD==1])-len(data_resampled[data_resampled.TenYearCHD==1].drop_duplicates()))
# Out:
# Number of duplicated samples: 0

# %% [markdown]
# <p>The dataset modelled by SMOTE has very high values for accuracy and recall, which is very good in this situation.</p>
#
# <p>Even the number of duplicated samples is 0 which is a very good new.</p>

# %% [markdown]
# <h3>5.2.3 ROC Curves</h3>

# %%
#ROC CURVES

plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_svm_original, tpr_svm_original, label='Original dataset')
plt.plot(fpr_svm_under, tpr_svm_under, label='Undersampling')
plt.plot(fpr_svm_over, tpr_svm_over, label='Oversampling')
plt.plot(fpr_svm_smote, tpr_svm_smote, label='Smote')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curves')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>It is clear by having a look at the ROC curves that Oversampling and SMOTE are good, while undersampling is doing really badly with SVM. The original dataset doesn't work good either when using SVM on it without any data balancing.</p>

# %% [markdown]
# <h2>5.3 Logistic Regression</h2>

# %% [markdown]
# <p>The goal is to be able to determine whether a patient will suffer a CHD in 10 years or not, based on his current vital parameters. So "TenYearCHD" will be considered as the dependent variable to be forecasted, while all the other columns will be considered the independent variables.</p>
#
# <p>First, it is needed to check which combination of parameters will allow to classificate records. It is not needed to use all of them: a simpler model would be suggested if possible.</p>

# %% [markdown]
# <h3>5.3.1 Fitting the data</h3>

# %%
def print_columns_with_exceptions(columns, exceptions):
    result = ""
    for col in set(columns)-set(exceptions):
        result = "{}+{}".format(col,result)
    return result[:len(result)-1]

# %%
exc =["TenYearCHD"]

X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(u_data.columns,exc)),u_data).fit()

y_pred = model.predict(X_test)

fpr_lr_original, tpr_lr_original, threshold_lr_original = roc_curve(y_test, y_pred)

print("Logistic Regression on the original dataset\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.197044
#          Iterations 9
# Logistic Regression on the original dataset
#
# Error: 0.13693846466605528
# MSE: 0.08661907807207149
#
# Confusion Matrix:
# [[872 113]
#  [ 14 150]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93       985
#            1       0.57      0.91      0.70       164
#
#     accuracy                           0.89      1149
#    macro avg       0.78      0.90      0.82      1149
# weighted avg       0.93      0.89      0.90      1149
#
# Accuracy
# 0.8894691035683203
# ------------------------------------------------------

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:             TenYearCHD   No. Observations:                  992
# Model:                          Logit   Df Residuals:                      976
# Method:                           MLE   Df Model:                           15
# Date:                Mon, 26 Jul 2021   Pseudo R-squ.:                  0.7157
# Time:                        16:31:21   Log-Likelihood:                -195.47
# converged:                       True   LL-Null:                       -687.60
# Covariance Type:            nonrobust   LLR p-value:                3.168e-200
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -38.6379      3.476    -11.116      0.000     -45.450     -31.825
# ...

# %% [markdown]
# <p>The Pseudo $R^2$ value is good enough. It could be interesting to see how the dataset perform with undersampling/oversampling/SMOTE would perform.</p>

# %% [markdown]
# <h3>5.3.2 Dataset balancing</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(u_data.columns,exc)),u_data).fit()
y_pred_under = model.predict(X_test)

fpr_lr_under, tpr_lr_under, threshold_lr_under = roc_curve(y_test, y_pred_under)

print("Undersampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")


X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(o_data.columns,exc)),o_data).fit()
y_pred_over = model.predict(X_test)

fpr_lr_over, tpr_lr_over, threshold_lr_over = roc_curve(y_test, y_pred_over)

print("Oversampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")



X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(data_resampled.columns,exc)),data_resampled).fit()
y_pred_smote = model.predict(X_test)

fpr_lr_smote, tpr_lr_smote, threshold_lr_smote = roc_curve(y_test, y_pred_smote)

print("SMOTE\n")
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.197044
#          Iterations 9
# Undersampling
#
# Error: 0.11397932626986461
# MSE: 0.05784634047472397
#
# Confusion Matrix:
# [[131  15]
#  [ 10 142]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       146
#            1       0.90      0.93      0.92       152
#
#     accuracy                           0.92       298
#    macro avg       0.92      0.92      0.92       298
# weighted avg       0.92      0.92      0.92       298
#
# Accuracy
# 0.9161073825503355
# ------------------------------------------------------
#
# Optimization terminated successfully.
#          Current function value: 0.214002
#          Iterations 9
# Oversampling
#
# Error: 0.12808625653368846
# MSE: 0.06283622300917442
#
# Confusion Matrix:
# [[796  87]
#  [ 57 846]]
#
# Classification Report
# ...

# %% [markdown]
# <h3>5.3.3 ROC curves comparison</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_original, tpr_lr_original, label='Original dataset')
plt.plot(fpr_lr_under, tpr_lr_under, label='Undersampling')
plt.plot(fpr_lr_over, tpr_lr_over, label='Oversampling')
plt.plot(fpr_lr_smote, tpr_lr_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>Either undersampling and oversampling have the best results wit this dataset. SMOTE is the one working the worse (slightly). In anycase, all of them work quite well.</p>

# %% [markdown]
# <h3>5.3.4 Data reduction and results</h3>

# %% [markdown]
# <p>Previously, it was discussed and showed the performance of logistic regression methods using all the columns. Now it will be shown how applying some data reduction techniques (dropping columns) would change its performance.</p>

# %%
# This code will compute the pseudo R^2 with all the columns.\n",
# Then it will compute it removing one by one all the columns with the
# highest p-value.
exc =["TenYearCHD"]
results = []
for i in range(1, len(data_resampled.columns)):
    columns = print_columns_with_exceptions(framingham.columns,exc)
    model = logit('TenYearCHD ~ {}'.format(columns),data_resampled).fit()
    results.append([columns, model.prsquared, model.llr_pvalue])
    exc.append(model.pvalues.idxmax())
    print("\nI removed the column \"{}\"\n".format(model.pvalues.idxmax()))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.277787
#          Iterations 8
#
# I removed the column "BMI"
#
# Optimization terminated successfully.
#          Current function value: 0.277816
#          Iterations 8
#
# I removed the column "heartRate"
#
# Optimization terminated successfully.
#          Current function value: 0.277860
#          Iterations 8
#
# I removed the column "prevalentStroke"
#
# Optimization terminated successfully.
#          Current function value: 0.277952
#          Iterations 8
#
# I removed the column "education"
#
# Optimization terminated successfully.
#          Current function value: 0.278248
#          Iterations 8
#
# I removed the column "cigsPerDay"
#
# Optimization terminated successfully.
#          Current function value: 0.279079
#          Iterations 8
#
# I removed the column "prevalentHyp"
#
# Optimization terminated successfully.
#          Current function value: 0.280168
#          Iterations 8
#
# ...

# %%
pd.DataFrame(data=results, columns=['Col','prsquared', 'llr-pvalue'])
# Out:
#                                                   Col  prsquared  \
# 0   glucose+sex+cigsPerDay+prevalentStroke+diabete...   0.599239
# 1   glucose+sex+cigsPerDay+prevalentStroke+diabete...   0.599196
# 2   glucose+sex+cigsPerDay+prevalentStroke+diabete...   0.599132
# 3   glucose+education+BPMeds+age+totChol+currentSm...   0.598999
# 4   glucose+sex+BPMeds+age+totChol+currentSmoker+c...   0.598573
# 5   glucose+sex+BPMeds+age+totChol+currentSmoker+d...   0.597374
# 6   glucose+sex+BPMeds+age+totChol+currentSmoker+d...   0.595802
# 7   glucose+sex+BPMeds+age+totChol+currentSmoker+d...   0.593931
# 8   currentSmoker+sex+BPMeds+age+totChol+diabetes+...   0.591658
# 9          currentSmoker+sex+BPMeds+age+totChol+sysBP   0.590775
# 10                currentSmoker+sex+age+totChol+sysBP   0.580843
# 11                    totChol+sysBP+currentSmoker+sex   0.542160
# 12                          totChol+currentSmoker+sex   0.417510
# ...

# %% [markdown]
# <p>Aguarbly, it would be fine to just use four columns ("currentSmoker","sysBP", "sex", "totChol") to compute logistic regression. It is possible to say so because the pseudo $R^2$ value is not too low and it is good to have a simplier model.</p>

# %%
exc = ['TenYearCHD','prevalentStroke','cigsPerDay','education','diaBP','prevalentHyp',\
       'BMI','age','glucose','heartRate','diabetes','BPMeds']

X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(u_data.columns,exc)),u_data).fit()

y_pred = model.predict(X_test)

fpr_lr_original_optimazed, tpr_lr_original_optimazed, threshold_lr_original_optimazed = roc_curve(y_test, y_pred)

print("Logistic Regression on the original dataset\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")



X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(u_data.columns,exc)),u_data).fit()
y_pred_under = model.predict(X_test)

fpr_lr_under_optimazed, tpr_lr_under_optimazed, threshold_lr_under_optimazed = roc_curve(y_test, y_pred_under)



print("Undersampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(o_data.columns,exc)),o_data).fit()
y_pred_over = model.predict(X_test)

fpr_lr_over_optimazed, tpr_lr_over_optimazed, threshold_lr_over_optimazed = roc_curve(y_test, y_pred_over)

print(model.prsquared)
print("Oversampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)
model = logit('TenYearCHD ~ {}'.format(print_columns_with_exceptions(data_resampled.columns,exc)),data_resampled).fit()
y_pred_smote = model.predict(X_test)

fpr_lr_smote_optimazed, tpr_lr_smote_optimazed, threshold_lr_smote_optimazed = roc_curve(y_test, y_pred_smote)
plt.show()

print("SMOTE\n")
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.233750
#          Iterations 9
# Logistic Regression on the original dataset
#
# Error: 0.16123008107825038
# MSE: 0.0986295989020179
#
# Confusion Matrix:
# [[834 151]
#  [ 16 148]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       985
#            1       0.49      0.90      0.64       164
#
#     accuracy                           0.85      1149
#    macro avg       0.74      0.87      0.77      1149
# weighted avg       0.91      0.85      0.87      1149
#
# Accuracy
# 0.8546562228024369
# ------------------------------------------------------
#
# Optimization terminated successfully.
#          Current function value: 0.233750
#          Iterations 9
# Undersampling
#
# Error: 0.14421275511180187
# MSE: 0.07478907312325832
#
# Confusion Matrix:
# [[129  17]
#  [ 16 136]]
#
# Classification Report
# ...

# %%
plt.figure(figsize=(10,20))
plt.subplot(2,1,1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_original, tpr_lr_original, label='Original dataset')
plt.plot(fpr_lr_under, tpr_lr_under, label='Undersampling')
plt.plot(fpr_lr_over, tpr_lr_over, label='Oversampling')
plt.plot(fpr_lr_smote, tpr_lr_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve - Dataset with all columns')
plt.legend(loc='best')
plt.grid()
plt.subplot(2,1,2)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr_original_optimazed, tpr_lr_original_optimazed, label='Original dataset')
plt.plot(fpr_lr_under_optimazed, tpr_lr_under_optimazed, label='Undersampling')
plt.plot(fpr_lr_over_optimazed, tpr_lr_over_optimazed, label='Oversampling')
plt.plot(fpr_lr_smote_optimazed, tpr_lr_smote_optimazed, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve - Dataset with 4 columns')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>Reducing the number of columns meant losing some precision (and having a slightly worse ROC curve), but the model is still doing very well while being simplier (4 columns instead of 14).</p>

# %% [markdown]
# <h2>5.4 MAP</h2>

# %% [markdown]
# <p>MAP (Maximum A Posteriori) is a classification method based on statistics, Bayes' rules to be more specific.</p>
#
# <p>It is used to assign labels on data based on their posterior probability: the label assigned is the one of the class having the highest posterior probability.</p>
#
# <p>In this project, it was used the Naive Bayes method, that allows an easier time to compute MAP because the dataset is multi-dimensional.</p>

# %% [markdown]
# <h3>5.4.1 Fitting the data</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)
model = GaussianNB().fit(X_train,y_train)
y_pred = model.predict(X_test)

fpr_map_original, tpr_map_original, threshold_map_original = roc_curve(y_test, y_pred)

print("MAP\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
# Out:
# MAP
#
# Error: 0.12532637075718014
# MSE: 0.12532637075718014
#
# Confusion Matrix:
# [[919  66]
#  [ 78  86]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93       985
#            1       0.57      0.52      0.54       164
#
#     accuracy                           0.87      1149
#    macro avg       0.74      0.73      0.74      1149
# weighted avg       0.87      0.87      0.87      1149
#
# Accuracy
# 0.8746736292428199

# %% [markdown]
# <p>The base dataset (without data balancing) has a good accuracy, but the F1 Score doesn't look too well.</p>
#
# <p>As usual, it is suggested to proceed with the data balancing.</p>

# %% [markdown]
# <h3>5.4.2 Dataset balancing</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)
model = GaussianNB().fit(X_train,y_train)
y_pred_under = model.predict(X_test)

fpr_map_under, tpr_map_under, threshold_map_under = roc_curve(y_test, y_pred_under)



print("Undersampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)
model = GaussianNB().fit(X_train,y_train)
y_pred_over = model.predict(X_test)

fpr_map_over, tpr_map_over, threshold_map_over = roc_curve(y_test, y_pred_over)

print("Oversampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)
model = GaussianNB().fit(X_train,y_train)
y_pred_smote = model.predict(X_test)

fpr_map_smote, tpr_map_smote, threshold_map_smote = roc_curve(y_test, y_pred_smote)

print("SMOTE\n")
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Undersampling
#
# Error: 0.10738255033557047
# MSE: 0.10738255033557047
#
# Confusion Matrix:
# [[132  14]
#  [ 18 134]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       146
#            1       0.91      0.88      0.89       152
#
#     accuracy                           0.89       298
#    macro avg       0.89      0.89      0.89       298
# weighted avg       0.89      0.89      0.89       298
#
# Accuracy
# 0.8926174496644296
# ------------------------------------------------------
#
# Oversampling
#
# Error: 0.1506159014557671
# MSE: 0.1506159014557671
#
# Confusion Matrix:
# [[767 116]
#  [153 750]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       883
#            1       0.87      0.83      0.85       903
#
#     accuracy                           0.85      1786
# ...

# %% [markdown]
# <h3>5.4.3 ROC Curves</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_map_original, tpr_map_original, label='Original dataset')
plt.plot(fpr_map_under, tpr_map_under, label='Undersampling')
plt.plot(fpr_map_over, tpr_map_over, label='Oversampling')
plt.plot(fpr_map_smote, tpr_map_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>In this case they all perform very well (except the original dataset which is unbalanced as said) and it is interesting to note that with MAP the undersampling works better than the others (even if it is slightly better).</p>

# %% [markdown]
# <h2>5.5 K-NN</h2>

# %% [markdown]
# <h3>5.5.1 Best K and optimizations</h3>

# %% [markdown]
# <p>Differently than the other classifiers, in this case operations of data optimizations (best K predictor, multi-editing, condensing) will be performed before fitting the data.</p>
#
# <p>First operation to perform is the search of the best K.</p>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)

# %%
param_grid = [ {'n_neighbors':range(1,100)}]
gs = GridSearchCV(KNN(), param_grid)
gs.fit(X_train, y_train)
best_knn = gs.best_estimator_
print("Best K value is: %d" % best_knn.n_neighbors)
# Out:
# Best K value is: 7

# %% [markdown]
# <p>Is it possible to lower it? 7 is not such a bad value after all. Anyway, let's take a look at what happens after performing multi-editing and condensing. First comes the multi-editing operation:</p>

# %%
def multiedit(data, target, s=5, T=3):
    
    all_indices = np.array(range(len(data)))
    finished = False
    iterations_since_last_change = 0
    knn = KNN(n_neighbors=1)
    while not finished:
        edited = False
        
        split_indices = np.array_split(np.random.permutation(all_indices),s)
    
        mark_for_removal = []

        for i in range(s):
            j = (i+1)%s
            idx_test = split_indices[i]
            idx_train = split_indices[j]
            
            knn.fit(data[idx_train],target[idx_train])
            
            predictions = knn.predict(data[idx_test])
            
            mark_for_removal.extend(idx_test[np.where(predictions!=target[idx_test])])
            
            if all(predictions!=target[idx_test]):
                edited = True
                
        all_indices = np.setdiff1d(all_indices, mark_for_removal)
        
        if not edited:
            iterations_since_last_change+=1
            
        if iterations_since_last_change>=T:
            finished=True
    
    multiedited_data, multiedited_target = data[all_indices], target[all_indices]
    
    
    columns = list(framingham.columns)[:-1]
    data_multiedited = pd.DataFrame()
    i = 0
    for col in columns:
        data_multiedited[col] = multiedited_data[:,i]
        i += 1

    data_multiedited['TenYearCHD'] = multiedited_target
    return data_multiedited

# %%
data_multiedited = multiedit(X_train.values, y_train.values)

# %% [markdown]
# <p>Now it follows a comparison with the base dataset and the edited one using 1-nn:</p>

# %%
knn = KNN(n_neighbors=1)
knn_multiedited = KNN(n_neighbors=1)
knn.fit(X_train, y_train)
knn_multiedited.fit(data_multiedited.drop('TenYearCHD',axis=1), data_multiedited.TenYearCHD)

print("Accuracy of 1-NN on the original dataset: %0.2f" % \
    knn.score(X_test, y_test))
print("Accuracy of 1-NN on the dataset after multi-editing: %0.2f" % \
    knn_multiedited.score(X_test, y_test))
# Out:
# Accuracy of 1-NN on the original dataset: 0.85
# Accuracy of 1-NN on the dataset after multi-editing: 0.87

# %% [markdown]
# <p>It slightly increased the accuracy of the dataset. Good. Let's now perform condensing operations:</p>

# %%
def condense(data, target):
    selected = np.zeros(len(data)).astype(bool)
    
    i = np.random.choice(range(len(data)))
    selected[i] = 1
   
    knn = KNN(n_neighbors=1)
    finished = False
    while not finished:
        selected_new_elements = False
        for i in range(len(data)):
            if not selected[i]:
                knn.fit(data[selected],target[selected])
                if knn.predict(data[i].reshape((1,15)))[0]!=target[i]:
                    selected[i]=1
                    selected_new_elements = True
        if selected_new_elements == False:
            finished=True
    condensed_data, condensed_target = data[selected], target[selected]
    
    columns = list(framingham.columns)[:-1]
    data_condensed = pd.DataFrame()
    i = 0
    for col in columns:
        data_condensed[col] = condensed_data[:,i]
        i += 1

    data_condensed['TenYearCHD'] = condensed_target
    return data_condensed

# %%
data_condensed = condense(data_multiedited.drop('TenYearCHD',axis=1).values, data_multiedited['TenYearCHD'].values)
print("Number of samples in the original dataset: %d" % len(X_train))
print("Number of samples in the training set: %d" % len(data_condensed))
print("Samples removed: {:.2f}%".format(float(len(X_train)-len(data_condensed))/len(X_train)*100))
# Out:
# Number of samples in the original dataset: 2678
# Number of samples in the training set: 54
# Samples removed: 97.98%

# %%
knn = KNN(n_neighbors=1)
knn_condensed = KNN(n_neighbors=1)
knn.fit(X_train, y_train)
knn_condensed.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed['TenYearCHD'])

print("Accuracy of 1-NN on the original dataset: %0.2f" % \
    knn.score(X_test, y_test))
print("Accuracy of 1-NN on the dataset after condensing: %0.2f" % \
    knn_condensed.score(X_test, y_test))
# Out:
# Accuracy of 1-NN on the original dataset: 0.85
# Accuracy of 1-NN on the dataset after condensing: 0.87

# %% [markdown]
# <p>It is probably the perfect situation: the accuracy should be the same and the dataset has been reduced significately (PS: values may vary every time the code runs). Now it is possible to search for the best K value again and see if it updates too:</p>

# %%
param_grid = [ {'n_neighbors':range(1,25)}]
gs = GridSearchCV(KNN(), param_grid)
gs.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed['TenYearCHD'])
best_knn = gs.best_estimator_
print("Best K value is: %d" % best_knn.n_neighbors)
# Out:
# Best K value is: 4

# %% [markdown]
# <p>The value has decreased which is the expected result. It is important to say that the difference from the K found early on  (7) it is  probably not that high, but it shows that the dataset can be optimized.</p>
#
# <p>Now the dataset has been reduced and the algorithm can run faster and can be more efficient.</p>

# %% [markdown]
# <h3>5.5.2 Fitting the data from the original dataset</h3>

# %%
k = best_knn.n_neighbors

knn = KNN(n_neighbors=k)
y_pred = model.predict(X_test)

fpr_knn_original, tpr_knn_original, threshold_knn_original = roc_curve(y_test, y_pred)

print("K-NN on the original dataset\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")



knn_edited = KNN(n_neighbors=k)
model_edited = knn_edited.fit(data_multiedited.drop('TenYearCHD',axis=1), data_multiedited['TenYearCHD'])
y_pred_edited = model_edited.predict(X_test)

fpr_knn_edited, tpr_knn_edited, threshold_knn_edited = roc_curve(y_test, y_pred_edited)

print("K-NN after multi-editing\n")
print("Error:",mean_absolute_error(y_test, y_pred_edited))
print("MSE:",mean_squared_error(y_test, y_pred_edited))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_edited.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_edited.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_edited.round(), normalize=True))
print("------------------------------------------------------\n")


knn_condensed = KNN(n_neighbors=k)
model_condensed = knn_condensed.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed['TenYearCHD'])
y_pred_condensed = model_condensed.predict(X_test)

fpr_knn_condensed, tpr_knn_condensed, threshold_knn_condensed = roc_curve(y_test, y_pred_condensed)

print("K-NN after condensing\n")
print("Error:",mean_absolute_error(y_test, y_pred_condensed))
print("MSE:",mean_squared_error(y_test, y_pred_condensed))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_condensed.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_condensed.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_condensed.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# K-NN on the original dataset
#
# Error: 0.19495213228894692
# MSE: 0.19495213228894692
#
# Confusion Matrix:
# [[775 210]
#  [ 14 150]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.79      0.87       985
#            1       0.42      0.91      0.57       164
#
#     accuracy                           0.81      1149
#    macro avg       0.70      0.85      0.72      1149
# weighted avg       0.90      0.81      0.83      1149
#
# Accuracy
# 0.8050478677110531
# ------------------------------------------------------
#
# K-NN after multi-editing
#
# Error: 0.1392515230635335
# MSE: 0.1392515230635335
#
# Confusion Matrix:
# [[985   0]
#  [160   4]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       985
#            1       1.00      0.02      0.05       164
#
#     accuracy                           0.86      1149
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_knn_original, tpr_knn_original, label='Original dataset')
plt.plot(fpr_knn_edited, tpr_knn_edited, label='After Editing')
plt.plot(fpr_knn_condensed, tpr_knn_condensed, label='After condensing')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>As shown, the original dataset is not exactly the best baseline where to start editing and condensing: those operations lead to a situation where the classifier work very badly.</p>
#
# <p>The problem is the fact that the dataset is unbalanced:</p>

# %%
plt.figure(figsize=(16,6))
plt.title('Samples per class after Multi-editing')
counts = data_multiedited['TenYearCHD'].value_counts()
plt.bar(["False","True"],counts)
plt.grid()

plt.figure(figsize=(16,6))
plt.title('Samples per class after Condensing')
counts = data_condensed['TenYearCHD'].value_counts()
plt.bar(["False","True"],counts)
plt.grid()

# %% [markdown]
# <p>It is needed to perform data balancing before.</p>

# %% [markdown]
# <h3>5.3.3 Dataset balancing</h3>

# %%
param_grid = [ {'n_neighbors':range(1,25)}]

X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)
data_multiedited = multiedit(X_train.values, y_train.values) 
data_condensed = condense(data_multiedited.drop('TenYearCHD',axis=1).values, data_multiedited['TenYearCHD'].values)

gs = GridSearchCV(KNN(), param_grid)
gs.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed.TenYearCHD)
y_pred_under = gs.best_estimator_.predict(X_test)

fpr_knn_under, tpr_knn_under, threshold_knn_under = roc_curve(y_test, y_pred_under)



print("Undersampling\n")
print("K value:", gs.best_estimator_.n_neighbors)
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")


X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)
data_multiedited = multiedit(X_train.values, y_train.values) 
data_condensed = condense(data_multiedited.drop('TenYearCHD',axis=1).values, data_multiedited['TenYearCHD'].values)

gs = GridSearchCV(KNN(), param_grid)
gs.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed.TenYearCHD)
y_pred_over = gs.best_estimator_.predict(X_test)

fpr_knn_over, tpr_knn_over, threshold_knn_over = roc_curve(y_test, y_pred_over)

print("Oversampling\n")
print("K value:", gs.best_estimator_.n_neighbors)
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")


X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)
data_multiedited = multiedit(X_train.values, y_train.values) 
data_condensed = condense(data_multiedited.drop('TenYearCHD',axis=1).values, data_multiedited['TenYearCHD'].values)

gs = GridSearchCV(KNN(), param_grid)
gs.fit(data_condensed.drop('TenYearCHD',axis=1), data_condensed.TenYearCHD)
y_pred_smote = gs.best_estimator_.predict(X_test)

fpr_knn_smote, tpr_knn_smote, threshold_knn_smote = roc_curve(y_test, y_pred_smote)

print("SMOTE\n")
print("K value:", gs.best_estimator_.n_neighbors)
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Undersampling
#
# K value: 17
# Error: 0.27181208053691275
# MSE: 0.27181208053691275
#
# Confusion Matrix:
# [[111  35]
#  [ 46 106]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.76      0.73       146
#            1       0.75      0.70      0.72       152
#
#     accuracy                           0.73       298
#    macro avg       0.73      0.73      0.73       298
# weighted avg       0.73      0.73      0.73       298
#
# Accuracy
# 0.7281879194630873
# ------------------------------------------------------
#
# Oversampling
#
# K value: 17
# Error: 0.2122060470324748
# MSE: 0.2122060470324748
#
# Confusion Matrix:
# [[721 162]
#  [217 686]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       883
#            1       0.81      0.76      0.78       903
#
#     accuracy                           0.79      1786
# ...

# %% [markdown]
# <h3>5.5.4 ROC Curves</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_knn_condensed, tpr_knn_condensed, label='Original dataset')
plt.plot(fpr_knn_under, tpr_knn_under, label='Undersampling')
plt.plot(fpr_knn_over, tpr_knn_over, label='Oversampling')
plt.plot(fpr_knn_smote, tpr_knn_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>After the operations to balance the dataset, the K-NN classifier performs better. It is obvious by looking at the picture that all of the three methods of data balancing work way better than using the original unbalanced dataset. Anyway these classifiers perform worse than SVM, Logistic Regression and MAP.</p>
#
# <p><b>PS</b>: since multi-editing and condensing introduce random operations (since they split randomically the dataset many times) the results for this section and the previous could change any time the code runs, but it generally shows results that are similar to what it was stated in these sections.</p>

# %% [markdown]
# <h2>5.6 Random Forest</h2>

# %% [markdown]
# <p>Random forests are an ensemble learning method for classification, regression and other tasks that operates by constructing a multitude of decision trees at training time. For classification tasks, the output of the random forest is the class selected by most trees.</p>
#
# <p>The technique used to compose the results from many decision trees is called "bagging", a method where every classifier has the same importance to compute the predictions. Later on (section 5.7) a different boosting method will be shown when presenting AdaBoost.</p>
#
# <p>For this project it was decided to use 100 trees with max depth 3.</p>

# %% [markdown]
# <h3>5.6.1 Fitting the data</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)

rfc = RandomForestClassifier(max_depth=3, n_estimators=100)

model = rfc.fit(X_train, y_train)
 
y_pred = model.predict(X_test)

fpr_original, tpr_original, threshold_original = roc_curve(y_test, y_pred)

print("Random Forrest\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Random Forrest
#
# Error: 0.13489991296779807
# MSE: 0.13489991296779807
#
# Confusion Matrix:
# [[985   0]
#  [155   9]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       985
#            1       1.00      0.05      0.10       164
#
#     accuracy                           0.87      1149
#    macro avg       0.93      0.53      0.52      1149
# weighted avg       0.88      0.87      0.81      1149
#
# Accuracy
# 0.8651000870322019
# ------------------------------------------------------

# %% [markdown]
# <p>Accuracy is very high, but the classifiers don't really work well with the unbalanced dataset (the minority class has a very low recall).</p>

# %% [markdown]
# <h3>5.6.2 Dataset balancing</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)

rfc = RandomForestClassifier(max_depth=3, n_estimators=100)

model = rfc.fit(X_train, y_train)

y_pred_under = model.predict(X_test)

fpr_under, tpr_under, threshold_under = roc_curve(y_test, y_pred_under)



print("Undersampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)

rfc = RandomForestClassifier(max_depth=3, n_estimators=100)

model = rfc.fit(X_train, y_train)

y_pred_over = model.predict(X_test)

fpr_over, tpr_over, threshold_over = roc_curve(y_test, y_pred_over)

print("Oversampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)

rfc = RandomForestClassifier(max_depth=3, n_estimators=100)

model = rfc.fit(X_train, y_train)

y_pred_smote = model.predict(X_test)

fpr_smote, tpr_smote, threshold_smote = roc_curve(y_test, y_pred_smote)

print("SMOTE\n")
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Undersampling
#
# Error: 0.10067114093959731
# MSE: 0.10067114093959731
#
# Confusion Matrix:
# [[126  20]
#  [ 10 142]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       146
#            1       0.88      0.93      0.90       152
#
#     accuracy                           0.90       298
#    macro avg       0.90      0.90      0.90       298
# weighted avg       0.90      0.90      0.90       298
#
# Accuracy
# 0.8993288590604027
# ------------------------------------------------------
#
# Oversampling
#
# Error: 0.11926091825307951
# MSE: 0.11926091825307951
#
# Confusion Matrix:
# [[738 145]
#  [ 68 835]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.87       883
#            1       0.85      0.92      0.89       903
#
#     accuracy                           0.88      1786
# ...

# %% [markdown]
# <h3>5.6.3 ROC Curves</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_original, tpr_original, label='Original dataset')
plt.plot(fpr_under, tpr_under, label='Undersampling')
plt.plot(fpr_over, tpr_over, label='Oversampling')
plt.plot(fpr_smote, tpr_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>As noted in the previous section, Random Forrest performs really badly with the unbalanced original dataset. Data balancing solve this problem as the graphic shows: all of them have nicer ROC Curves, with similar performances.</p>

# %% [markdown]
# <h2>5.7 ADABoost combined with Decision Tree classifier</h2>

# %% [markdown]
# <p>AdaBoost, short for Adaptive Boosting, is a statistical classification meta-algorithm formulated by Yoav Freund and Robert Schapire. It can be used in conjunction with many other types of learning algorithms to improve performance.</p>
#
# <p>Problems in machine learning often come from the curse of dimensionality — each sample may consist of a huge number of potential features, and evaluating every feature can reduce not only the speed of classifier training and execution, but in fact reduce predictive power. Unlike neural networks and SVMs, the AdaBoost training process selects only those features known to improve the predictive power of the model, reducing dimensionality and potentially improving execution time as irrelevant features don't need to be computed.</p>
#
# <p>For this classifier, it will be shown how the basic classifier (Decision Tree) performs as it has been done with the other classifiers.</p>

# %% [markdown]
# <h3>5.7.1 Fitting the data</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(framingham.drop('TenYearCHD', axis=1), framingham.TenYearCHD, test_size=0.3, random_state=seed)

abc = AdaBoostClassifier(random_state=seed)

model = abc.fit(X_train, y_train)
 
y_pred = model.predict(X_test)

fpr_original, tpr_original, threshold_original = roc_curve(y_test, y_pred)

print("AdaBoost\n")
print("Error:",mean_absolute_error(y_test, y_pred))
print("MSE:",mean_squared_error(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# AdaBoost
#
# Error: 0.04177545691906005
# MSE: 0.04177545691906005
#
# Confusion Matrix:
# [[976   9]
#  [ 39 125]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       985
#            1       0.93      0.76      0.84       164
#
#     accuracy                           0.96      1149
#    macro avg       0.95      0.88      0.91      1149
# weighted avg       0.96      0.96      0.96      1149
#
# Accuracy
# 0.95822454308094
# ------------------------------------------------------

# %% [markdown]
# <h3>5.7.2 Dataset balancing</h3>

# %%
X_train, X_test, y_train, y_test =\
train_test_split(u_data.drop('TenYearCHD', axis=1), u_data.TenYearCHD, test_size=0.3, random_state=seed)

abc = AdaBoostClassifier(random_state=seed)

model = abc.fit(X_train, y_train)

y_pred_under = model.predict(X_test)

fpr_under, tpr_under, threshold_under = roc_curve(y_test, y_pred_under)



print("Undersampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_under))
print("MSE:",mean_squared_error(y_test, y_pred_under))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_under.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_under.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_under.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(o_data.drop('TenYearCHD', axis=1), o_data.TenYearCHD, test_size=0.3, random_state=seed)

abc = AdaBoostClassifier(random_state=seed)

model = abc.fit(X_train, y_train)

y_pred_over = model.predict(X_test)

fpr_over, tpr_over, threshold_over = roc_curve(y_test, y_pred_over)

print("Oversampling\n")
print("Error:",mean_absolute_error(y_test, y_pred_over))
print("MSE:",mean_squared_error(y_test, y_pred_over))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_over.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_over.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_over.round(), normalize=True))
print("------------------------------------------------------\n")

X_train, X_test, y_train, y_test =\
train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=seed)

abc = AdaBoostClassifier(random_state=seed)

model = abc.fit(X_train, y_train)

y_pred_smote = model.predict(X_test)

fpr_smote, tpr_smote, threshold_smote = roc_curve(y_test, y_pred_smote)

print("SMOTE\n")
print("Error:",mean_absolute_error(y_test, y_pred_smote))
print("MSE:",mean_squared_error(y_test, y_pred_smote))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_smote.round()))
print("\nClassification Report")
print(classification_report(y_test, y_pred_smote.round()))
print("Accuracy")
print(accuracy_score(y_test, y_pred_smote.round(), normalize=True))
print("------------------------------------------------------\n")
# Out:
# Undersampling
#
# Error: 0.040268456375838924
# MSE: 0.040268456375838924
#
# Confusion Matrix:
# [[138   8]
#  [  4 148]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       146
#            1       0.95      0.97      0.96       152
#
#     accuracy                           0.96       298
#    macro avg       0.96      0.96      0.96       298
# weighted avg       0.96      0.96      0.96       298
#
# Accuracy
# 0.959731543624161
# ------------------------------------------------------
#
# Oversampling
#
# Error: 0.02967525195968645
# MSE: 0.02967525195968645
#
# Confusion Matrix:
# [[842  41]
#  [ 12 891]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       883
#            1       0.96      0.99      0.97       903
#
#     accuracy                           0.97      1786
# ...

# %% [markdown]
# <h3>5.7.3 ROC Curves</h3>

# %%
plt.figure(figsize=(10,10))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_original, tpr_original, label='Original dataset')
plt.plot(fpr_under, tpr_under, label='Undersampling')
plt.plot(fpr_over, tpr_over, label='Oversampling')
plt.plot(fpr_smote, tpr_smote, label='SMOTE')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# <p>Using ADA Boost combined with the decision trees classifier, datasets generated by data balancing methods works better than the original dataset. They are quite close in the plot and it seems that the oversampling works slightly better than the others.</p>

# %% [markdown]
# <h1>6 Conclusions</h1>

# %% [markdown]
# <p>Despite being a simple project and a very superficial study (considering how deeper we could go when studying a social phenomenon), it was very interesting to study many different classification methods and compare their results. Plus, it was my first in-depth attempt with the common tools used by data scientist.</p>
#
# <p>If I would continue with this project, I'd add a more in-depth study of each classificator (for instance, I would explore more the Ada Boost with different type of estimators) and I would test this with external data (similar structured data, but from another sample). Another strategy that I'd like to study would be clustering: in this project it wasn't taken in consideration since it would have been impossible to show maps/graphics without using data reduction (either PCA or SOM). It would be a great addition to implement PCA/SOM and then perform K-Means for example.</p>

# %% [markdown]
# <h1>References</h1>

# %% [markdown]
# <ol>
#     <li><a href="https://en.wikipedia.org/wiki/Framingham_Risk_Score">https://en.wikipedia.org/wiki/Framingham_Risk_Score</a></li>
# </ol>
